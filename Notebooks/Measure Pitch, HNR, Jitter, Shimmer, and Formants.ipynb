# %% [markdown]
# # Measure Pitch, HNR, Jitter, Shimmer, Formants, and Estimate VTL

# %% [markdown]
# ### The extracted features
# * voiceID
# * duration
# * meanF0Hz
# * stdevF0Hz
# * HNR
# * localJitter
# * localabsoluteJitter
# * rapJitter
# * ppq5Jitter
# * ddpJitter
# * localShimmer
# * localdbShimmer
# * apq3Shimmer
# * apq5Shimmer
# * apq11Shimmer
# * ddaShimmer
# * f1_mean
# * f2_mean
# * f3_mean
# * f4_mean
# * f1_median
# * f2_median
# * f3_median
# * f4_median
# * JitterPCA
# * ShimmerPCA
# * pF
# * fdisp
# * avgFormant
# * mff
# * fitch_vtl
# * delta_f
# * vtl_delta_f

# %% [markdown]
# ## Import the external modules

# %%
#!/usr/bin/env python3
import glob
import numpy as np
import pandas as pd
import parselmouth 
import statistics
import librosa
import noisereduce as nr
import scipy.stats as stats
from concurrent.futures import ThreadPoolExecutor
import scipy

from pydub import AudioSegment
from parselmouth.praat import call
from scipy.stats.mstats import zscore
from scipy.stats import mode as scipy_mode
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## This function measures duration, pitch, HNR, jitter, and shimmer

# %%
# This is the function to measure source acoustics using default male parameters.

def measurePitch(audio, sr, sound, f0min, f0max, unit):
    sound = parselmouth.Sound(sound) # read the sound
    duration = call(sound, "Get total duration") # duration
    pitch = call(sound, "To Pitch", 0.0, f0min, f0max) #create a praat pitch object
    meanF0 = call(pitch, "Get mean", 0, 0, unit) # get mean pitch
    stdevF0 = call(pitch, "Get standard deviation", 0 ,0, unit) # get standard deviation
    harmonicity = call(sound, "To Harmonicity (cc)", 0.01, f0min, 0.1, 1.0)
    hnr = call(harmonicity, "Get mean", 0, 0)
    pointProcess = call(sound, "To PointProcess (periodic, cc)", f0min, f0max)
    localJitter = call(pointProcess, "Get jitter (local)", 0, 0, 0.0001, 0.02, 1.3)
    localabsoluteJitter = call(pointProcess, "Get jitter (local, absolute)", 0, 0, 0.0001, 0.02, 1.3)
    rapJitter = call(pointProcess, "Get jitter (rap)", 0, 0, 0.0001, 0.02, 1.3)
    ppq5Jitter = call(pointProcess, "Get jitter (ppq5)", 0, 0, 0.0001, 0.02, 1.3)
    ddpJitter = call(pointProcess, "Get jitter (ddp)", 0, 0, 0.0001, 0.02, 1.3)
    localShimmer =  call([sound, pointProcess], "Get shimmer (local)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    localdbShimmer = call([sound, pointProcess], "Get shimmer (local_dB)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    apq3Shimmer = call([sound, pointProcess], "Get shimmer (apq3)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    aqpq5Shimmer = call([sound, pointProcess], "Get shimmer (apq5)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    apq11Shimmer =  call([sound, pointProcess], "Get shimmer (apq11)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    ddaShimmer = call([sound, pointProcess], "Get shimmer (dda)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    
    return duration, meanF0, stdevF0, hnr, localJitter, localabsoluteJitter, rapJitter, ppq5Jitter, ddpJitter, localShimmer, localdbShimmer, apq3Shimmer, aqpq5Shimmer, apq11Shimmer, ddaShimmer

# %% [markdown]
# ## This function measures formants at each glottal pulse
#
# Puts, D. A., Apicella, C. L., & Cárdenas, R. A. (2012). Masculine voices signal men's threat potential in forager and industrial societies. Proceedings of the Royal Society of London B: Biological Sciences, 279(1728), 601-609.
#
# Adapted from: DOI 10.17605/OSF.IO/K2BHS

# %%
# This function measures formants using Formant Position formula
def measureFormants(sound, wave_file, f0min,f0max):
    sound = parselmouth.Sound(sound) # read the sound
    pitch = call(sound, "To Pitch (cc)", 0, f0min, 15, 'no', 0.03, 0.45, 0.01, 0.35, 0.14, f0max)
    pointProcess = call(sound, "To PointProcess (periodic, cc)", f0min, f0max)
    
    formants = call(sound, "To Formant (burg)", 0.0025, 5, 5000, 0.025, 50)
    numPoints = call(pointProcess, "Get number of points")

    f1_list = []
    f2_list = []
    f3_list = []
    f4_list = []
    
    # Measure formants only at glottal pulses
    for point in range(0, numPoints):
        point += 1
        t = call(pointProcess, "Get time from index", point)
        f1 = call(formants, "Get value at time", 1, t, 'Hertz', 'Linear')
        f2 = call(formants, "Get value at time", 2, t, 'Hertz', 'Linear')
        f3 = call(formants, "Get value at time", 3, t, 'Hertz', 'Linear')
        f4 = call(formants, "Get value at time", 4, t, 'Hertz', 'Linear')
        f1_list.append(f1)
        f2_list.append(f2)
        f3_list.append(f3)
        f4_list.append(f4)
    
    f1_list = [f1 for f1 in f1_list if str(f1) != 'nan']
    f2_list = [f2 for f2 in f2_list if str(f2) != 'nan']
    f3_list = [f3 for f3 in f3_list if str(f3) != 'nan']
    f4_list = [f4 for f4 in f4_list if str(f4) != 'nan']
    
    # calculate mean formants across pulses
    f1_mean = statistics.mean(f1_list)
    f2_mean = statistics.mean(f2_list)
    f3_mean = statistics.mean(f3_list)
    f4_mean = statistics.mean(f4_list)
    
    # calculate median formants across pulses, this is what is used in all subsequent calcualtions
    # you can use mean if you want, just edit the code in the boxes below to replace median with mean
    f1_median = statistics.median(f1_list)
    f2_median = statistics.median(f2_list)
    f3_median = statistics.median(f3_list)
    f4_median = statistics.median(f4_list)
    
    return f1_mean, f2_mean, f3_mean, f4_mean, f1_median, f2_median, f3_median, f4_median

# %% [markdown]
# ## This function runs a 2-factor Principle Components Analysis (PCA) on Jitter and Shimmer

# %%
def runPCA(df):
    # z-score the Jitter and Shimmer measurements
    measures = ['localJitter', 'localabsoluteJitter', 'rapJitter', 'ppq5Jitter', 'ddpJitter',
                'localShimmer', 'localdbShimmer', 'apq3Shimmer', 'apq5Shimmer', 'apq11Shimmer', 'ddaShimmer']
    x = df.loc[:, measures].values
    x = StandardScaler().fit_transform(x)
    # PCA
    pca = PCA(n_components=2)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents, columns = ['JitterPCA', 'ShimmerPCA'])
    principalDf
    return principalDf

# %% [markdown]
# ## Preprocessing to the audio file

# %%
def remove_silence(audio):
    unsilenced = []
    time_intervals = librosa.effects.split(audio, top_db=25, ref=np.max).tolist()
    for start, end in time_intervals:
        unsilenced += audio.tolist()[start:end+1]
    unsilenced = np.array(unsilenced)

    return unsilenced

def normalize(audio): 
    rms = np.sqrt(np.mean(audio**2))
    current_db = 20 * np.log10(rms)
    target_db = -20.0
    gain = target_db - current_db
    audio_normalized = audio * (10**(gain / 20))
    return audio_normalized

def load_mp3(path):
    audio_segment = AudioSegment.from_file(path, format="mp3")
    # Ensure the audio is mono
    audio_segment = audio_segment.set_channels(1)
    # Convert AudioSegment to raw PCM data
    samples = np.array(audio_segment.get_array_of_samples(), dtype=np.float32)
    # Normalize the samples to the range [-1, 1]
    samples /= np.iinfo(audio_segment.array_type).max
    # Pass the samples and sampling rate to librosa
    sr = audio_segment.frame_rate
    return librosa.resample(samples, orig_sr=sr, target_sr=sr), sr

# %% [markdown]
# ## Enhanced parallel feature extraction

# %%
def measureSpecialFeatures(y, sr):
    if len(y) == 0 or np.max(np.abs(y)) < 1e-4:
        raise ValueError("Audio too quiet or empty for feature extraction.")

    try:
        n_fft = 2048
        stft = np.abs(librosa.stft(y, n_fft=n_fft))
        if stft.shape[1] == 0:
            raise ValueError("STFT produced empty output.")

        freqs = librosa.fft_frequencies(sr=sr, n_fft=n_fft)
        stft_sum = np.sum(stft, axis=0, keepdims=True)
        stft_norm = stft / (stft_sum + 1e-6)

        meanfreq = np.sum(freqs[:, None] * stft_norm, axis=0)
        spectral_flatness = librosa.feature.spectral_flatness(y=y)
        mean_spectral_flatness = np.mean(spectral_flatness)

        power_spectrum = stft**2
        psd_norm = power_spectrum / (np.sum(power_spectrum, axis=0, keepdims=True) + 1e-10)
        if np.isnan(psd_norm).any():
            raise ValueError("PSD normalization resulted in NaNs.")

        spectral_entropy = -np.sum(psd_norm * np.log2(psd_norm + 1e-10), axis=0)
        mean_spectral_entropy = np.mean(spectral_entropy)

        iqr_per_frame = scipy.stats.iqr(stft, axis=0)
        avg_iqr = np.mean(iqr_per_frame) / 1000

        std_meanfreq = np.std(meanfreq) / 1000
        q25 = np.percentile(meanfreq, 25) / 1000

        mode_freq = freqs[np.argmax(stft, axis=0)]
        mode_frequency = float(scipy_mode(mode_freq, keepdims=True).mode[0] / 1000)

        return {
            "IQR": float(avg_iqr),
            "sd": float(std_meanfreq),
            "sfm": float(mean_spectral_flatness),
            "Q25": float(q25),
            "sp.ent": float(mean_spectral_entropy),
            "mode": mode_frequency
        }
    except Exception as e:
        print(f"Error in measureSpecialFeatures: {e}")
        raise

# %%
# def measureSpecialFeatures(y, sr):
#     stft = np.abs(librosa.stft(y))
#     freqs = librosa.fft_frequencies(sr=sr)
#     meanfreq = np.sum(freqs[:, None] * stft, axis=0) / (np.sum(stft, axis=0) + 1e-6)
#     spectral_flatness = librosa.feature.spectral_flatness(y=y)[0]
#     spectral_entropy = -np.sum((stft**2) * np.log(stft**2 + 1e-10), axis=0) / np.log(stft.shape[0])
#     mode_freq = freqs[np.argmax(stft, axis=0)]

#     return {
#         "stft": stft,
#         "IQR": float(stats.iqr(meanfreq) / 1000),
#         "sd": float(np.std(meanfreq) / 1000),
#         "sfm": float(np.mean(spectral_flatness)),
#         "Q25": float(np.percentile(meanfreq, 25) / 1000),
#         "sp.ent": float(np.mean(spectral_entropy)),
#         "mode": float(scipy_mode(mode_freq, keepdims=True)[0][0] / 1000)
#     }

# %%
# Define the columns for the DataFrame ( the general features case)
columns = [
    'voiceID', 'duration', 'meanF0Hz', 'stdevF0Hz', 'HNR', "IQR", "sd", "sfm", "Q25", "sp.ent", "mode",
    'localJitter', 'localabsoluteJitter', 'rapJitter', 'ppq5Jitter', 'ddpJitter',
    'localShimmer', 'localdbShimmer', 'apq3Shimmer', 'apq5Shimmer', 'apq11Shimmer', 'ddaShimmer',
    'f1_mean', 'f2_mean', 'f3_mean', 'f4_mean',
    'f1_median', 'f2_median', 'f3_median', 'f4_median'
]

# %%
import pandas as pd
import glob
from concurrent.futures import ThreadPoolExecutor
import os

# Constants
BATCH_SIZE = 5000
# Function to extract features from a single audio file
def extract_features(file_path):
    try:
        # Load and preprocess the audio
        audio, sr = librosa.load('../Data/'+file_path, sr=None, mono=True)
        audio = remove_silence(audio)
        audio = normalize(audio)
        audio = nr.reduce_noise(y=audio, sr=sr)
        sound = parselmouth.Sound(audio, sampling_frequency=sr)
        # Extract features
        duration, meanF0, stdevF0, hnr, localJitter, localabsoluteJitter, rapJitter, ppq5Jitter, ddpJitter, \
        localShimmer, localdbShimmer, apq3Shimmer, aqpq5Shimmer, apq11Shimmer, ddaShimmer = measurePitch(
            audio, sr, sound, 75, 300, "Hertz"
        )

        f1_mean, f2_mean, f3_mean, f4_mean, f1_median, f2_median, f3_median, f4_median = measureFormants(
            sound, file_path, 75, 300
        )

        special = measureSpecialFeatures(audio, sr)

        f = {
            'voiceID': file_path,
            'duration': duration,
            'meanF0Hz': meanF0,
            'stdevF0Hz': stdevF0,
            'HNR': hnr,
            'localJitter': localJitter,
            'localabsoluteJitter': localabsoluteJitter,
            'rapJitter': rapJitter,
            'ppq5Jitter': ppq5Jitter,
            'ddpJitter': ddpJitter,
            'localShimmer': localShimmer,
            'localdbShimmer': localdbShimmer,
            'apq3Shimmer': apq3Shimmer,
            'apq5Shimmer': aqpq5Shimmer,
            'apq11Shimmer': apq11Shimmer,
            'ddaShimmer': ddaShimmer,
            'f1_mean': f1_mean,
            'f2_mean': f2_mean,
            'f3_mean': f3_mean,
            'f4_mean': f4_mean,
            'f1_median': f1_median,
            'f2_median': f2_median,
            'f3_median': f3_median,
            'f4_median': f4_median
        }
        f.update(special)
        return f

    except Exception as e:
        print(f"Failed to process {file_path}: {e}")
        return None

# Function to process and save in batches
def process_and_save_in_batches(df,type):
    audio_files= df['path']
    for i in range(0, len(audio_files), BATCH_SIZE):
        batch_files = audio_files[i:i + BATCH_SIZE]
        with ThreadPoolExecutor(max_workers=10) as executor:
            results = list(executor.map(extract_features, batch_files))

        df = pd.DataFrame([res for res in results if res], columns=columns)
        df.to_csv(f"../CSVs/{type}/{i // BATCH_SIZE}.csv", index=False)
        print(f"Saved batch {i // BATCH_SIZE} with {len(df)} entries.")
        del df  # Free memory


males_df = pd.read_csv("males.csv")
females_df = pd.read_csv("females.csv")
fifties_df = pd.read_csv("fifties.csv")
twenties_df = pd.read_csv("twenties.csv")
process_and_save_in_batches(males_df,"gender")
process_and_save_in_batches(females_df,"gender")
process_and_save_in_batches(fifties_df,"age")
process_and_save_in_batches(twenties_df,"age")
# Out:
# C:\Users\Karim Mahmoud\AppData\Local\Temp\ipykernel_13340\1101988000.py:12: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load('../Data/'+file_path, sr=None, mono=True)
# d:\anaconda\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Failed to process common_voice_en_555764.mp3:
# Failed to process common_voice_en_639067.mp3:
# Failed to process common_voice_en_639124.mp3:
# Failed to process common_voice_en_570623.mp3:
# Failed to process common_voice_en_513707.mp3:
# Failed to process common_voice_en_552706.mp3:
# Failed to process common_voice_en_566754.mp3:
# Failed to process common_voice_en_644850.mp3:
# Failed to process common_voice_en_608593.mp3:
# Failed to process common_voice_en_672296.mp3:
# Failed to process common_voice_en_493346.mp3:
# Failed to process common_voice_en_487152.mp3:
# Failed to process common_voice_en_19713510.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19713510.mp3'
# Failed to process common_voice_en_668563.mp3:
# Failed to process common_voice_en_549541.mp3:
# Failed to process common_voice_en_591799.mp3:
# Failed to process common_voice_en_502401.mp3:
# Failed to process common_voice_en_635518.mp3:
# Failed to process common_voice_en_21704.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_21704.mp3'
# Failed to process common_voice_en_74536.mp3:
# Failed to process common_voice_en_478093.mp3:
# Failed to process common_voice_en_443141.mp3:
# Failed to process common_voice_en_612060.mp3:
# Failed to process common_voice_en_583699.mp3:
# Failed to process common_voice_en_37830.mp3:
# Failed to process common_voice_en_483907.mp3:
# Failed to process common_voice_en_668318.mp3:
# Failed to process common_voice_en_81801.mp3:
# Failed to process common_voice_en_566312.mp3:
# Failed to process common_voice_en_666465.mp3:
# Failed to process common_voice_en_497106.mp3:
# Failed to process common_voice_en_488850.mp3:
# Failed to process common_voice_en_374031.mp3:
# Failed to process common_voice_en_552730.mp3:
# Failed to process common_voice_en_813.mp3:
# Failed to process common_voice_en_571708.mp3:
# Failed to process common_voice_en_19961426.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19961426.mp3'
# Failed to process common_voice_en_59962.mp3:
# Failed to process common_voice_en_537451.mp3:
# Failed to process common_voice_en_574669.mp3:
# Failed to process common_voice_en_612064.mp3:
# Failed to process common_voice_en_19540754.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19540754.mp3'
# Failed to process common_voice_en_497134.mp3:
# Failed to process common_voice_en_8731583.mp3:
# Failed to process common_voice_en_505210.mp3:
# Failed to process common_voice_en_60924.mp3:
# Failed to process common_voice_en_567460.mp3:
# Failed to process common_voice_en_479497.mp3:
# Failed to process common_voice_en_595475.mp3:
# Failed to process common_voice_en_19569689.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19569689.mp3'
# Failed to process common_voice_en_649136.mp3:
# Failed to process common_voice_en_566127.mp3:
# Failed to process common_voice_en_621482.mp3:
# Failed to process common_voice_en_38848.mp3:
# Failed to process common_voice_en_574014.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_574014.mp3'
# Failed to process common_voice_en_670380.mp3:
# Failed to process common_voice_en_546916.mp3:
# Failed to process common_voice_en_596214.mp3:
# Failed to process common_voice_en_498541.mp3:
# Failed to process common_voice_en_5170505.mp3:
# Failed to process common_voice_en_6215460.mp3:
# Failed to process common_voice_en_630310.mp3:
# Failed to process common_voice_en_668054.mp3:
# Failed to process common_voice_en_612690.mp3:
# Failed to process common_voice_en_528346.mp3:
# Failed to process common_voice_en_620644.mp3:
# Failed to process common_voice_en_499276.mp3:
# Failed to process common_voice_en_621726.mp3:
# Failed to process common_voice_en_132551.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_132551.mp3'
# Failed to process common_voice_en_464658.mp3:
# Failed to process common_voice_en_77600.mp3:
# Failed to process common_voice_en_478629.mp3:
# Failed to process common_voice_en_591349.mp3:
# Failed to process common_voice_en_67600.mp3:
# Failed to process common_voice_en_15904504.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_15904504.mp3'
# Failed to process common_voice_en_93264.mp3:
# Failed to process common_voice_en_624354.mp3:
# Failed to process common_voice_en_667163.mp3:
# Failed to process common_voice_en_643112.mp3:
# Failed to process common_voice_en_546998.mp3:
# Failed to process common_voice_en_604947.mp3:
# Failed to process common_voice_en_622932.mp3:
# Failed to process common_voice_en_656574.mp3:
# Failed to process common_voice_en_639261.mp3:
# Failed to process common_voice_en_72695.mp3:
# Failed to process common_voice_en_484423.mp3:
# Failed to process common_voice_en_73999.mp3:
# Failed to process common_voice_en_497716.mp3:
# Failed to process common_voice_en_496565.mp3:
# Failed to process common_voice_en_557530.mp3:
# Failed to process common_voice_en_511547.mp3:
# Failed to process common_voice_en_523075.mp3:
# Failed to process common_voice_en_499088.mp3:
# Failed to process common_voice_en_483457.mp3:
# Failed to process common_voice_en_57033.mp3:
# Failed to process common_voice_en_84225.mp3:
# Failed to process common_voice_en_533039.mp3:
# Failed to process common_voice_en_580449.mp3:
# Failed to process common_voice_en_517827.mp3:
# Failed to process common_voice_en_73981.mp3:
# Failed to process common_voice_en_82858.mp3:
# Failed to process common_voice_en_477987.mp3:
# Failed to process common_voice_en_17899383.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17899383.mp3'
# Failed to process common_voice_en_19100247.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19100247.mp3'
# Failed to process common_voice_en_581996.mp3:
# Failed to process common_voice_en_668468.mp3:
# Failed to process common_voice_en_567390.mp3:
# Failed to process common_voice_en_627202.mp3:
# Failed to process common_voice_en_528577.mp3:
# Failed to process common_voice_en_96598.mp3:
# Failed to process common_voice_en_19363252.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19363252.mp3'
# Failed to process common_voice_en_555265.mp3:
# Failed to process common_voice_en_18735480.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18735480.mp3'
# Failed to process common_voice_en_41564.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_41564.mp3'
# Failed to process common_voice_en_17932045.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17932045.mp3'
# Failed to process common_voice_en_584551.mp3:
# Failed to process common_voice_en_507773.mp3:
# Failed to process common_voice_en_61840.mp3:
# Failed to process common_voice_en_600400.mp3:
# Failed to process common_voice_en_592363.mp3:
# Failed to process common_voice_en_584881.mp3:
# Failed to process common_voice_en_17686517.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17686517.mp3'
# Failed to process common_voice_en_74544.mp3:
# Failed to process common_voice_en_19043713.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19043713.mp3'
# Failed to process common_voice_en_616769.mp3:
# Failed to process common_voice_en_578696.mp3:
# Failed to process common_voice_en_613290.mp3:
# Failed to process common_voice_en_74986.mp3:
# Failed to process common_voice_en_18456203.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18456203.mp3'
# Failed to process common_voice_en_18148372.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18148372.mp3'
# Failed to process common_voice_en_512594.mp3:
# Failed to process common_voice_en_499790.mp3:
# Failed to process common_voice_en_507427.mp3:
# Failed to process common_voice_en_17932256.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17932256.mp3'
# Failed to process common_voice_en_547533.mp3:
# Failed to process common_voice_en_538474.mp3:
# Failed to process common_voice_en_17258483.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17258483.mp3'
# Failed to process common_voice_en_642418.mp3:
# Failed to process common_voice_en_478642.mp3:
# Failed to process common_voice_en_221073.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_221073.mp3'
# Failed to process common_voice_en_499264.mp3:
# Failed to process common_voice_en_581049.mp3:
# Failed to process common_voice_en_523122.mp3:
# Failed to process common_voice_en_490822.mp3:
# Failed to process common_voice_en_547670.mp3:
# Failed to process common_voice_en_535667.mp3:
# Failed to process common_voice_en_122087.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_122087.mp3'
# Failed to process common_voice_en_627219.mp3:
# Failed to process common_voice_en_4029333.mp3:
# Failed to process common_voice_en_499390.mp3:
# Failed to process common_voice_en_673760.mp3:
# Failed to process common_voice_en_614248.mp3:
# Failed to process common_voice_en_493617.mp3:
# Failed to process common_voice_en_589636.mp3:
# Failed to process common_voice_en_79539.mp3:
# Failed to process common_voice_en_700169.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_700169.mp3'
# Failed to process common_voice_en_24034.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_24034.mp3'
# Failed to process common_voice_en_20160475.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_20160475.mp3'
# Failed to process common_voice_en_519194.mp3:
# Failed to process common_voice_en_92123.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_92123.mp3'
# Failed to process common_voice_en_658476.mp3:
# Failed to process common_voice_en_478740.mp3:
# Failed to process common_voice_en_536674.mp3:
# Failed to process common_voice_en_6532655.mp3:
# Failed to process common_voice_en_543434.mp3:
# Failed to process common_voice_en_57711.mp3:
# Failed to process common_voice_en_523102.mp3:
# Failed to process common_voice_en_512603.mp3:
# Failed to process common_voice_en_567180.mp3:
# Failed to process common_voice_en_77389.mp3:
# Failed to process common_voice_en_8603429.mp3:
# Failed to process common_voice_en_375842.mp3:
# Failed to process common_voice_en_649145.mp3:
# Failed to process common_voice_en_55024.mp3:
# Failed to process common_voice_en_77259.mp3:
# Failed to process common_voice_en_373919.mp3:
# Failed to process common_voice_en_17391489.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17391489.mp3'
# Failed to process common_voice_en_649181.mp3:
# Failed to process common_voice_en_92392.mp3:
# Failed to process common_voice_en_518312.mp3:
# Failed to process common_voice_en_521623.mp3:
# Failed to process common_voice_en_495297.mp3:
# Failed to process common_voice_en_547127.mp3:
# Failed to process common_voice_en_93254.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_93254.mp3'
# Failed to process common_voice_en_543585.mp3:
# Failed to process common_voice_en_613227.mp3:
# Failed to process common_voice_en_17735744.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17735744.mp3'
# Failed to process common_voice_en_19680331.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19680331.mp3'
# Failed to process common_voice_en_621896.mp3:
# Failed to process common_voice_en_628500.mp3:
# Failed to process common_voice_en_571702.mp3:
# Failed to process common_voice_en_98910.mp3:
# Failed to process common_voice_en_85942.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_85942.mp3'
# Failed to process common_voice_en_65247.mp3:
# Failed to process common_voice_en_18601311.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18601311.mp3'
# Failed to process common_voice_en_82385.mp3:
# Failed to process common_voice_en_38104.mp3:
# Failed to process common_voice_en_546879.mp3:
# Failed to process common_voice_en_18121428.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18121428.mp3'
# Failed to process common_voice_en_621237.mp3:
# Failed to process common_voice_en_658481.mp3:
# Failed to process common_voice_en_18479906.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18479906.mp3'
# Failed to process common_voice_en_18522241.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18522241.mp3'
# Failed to process common_voice_en_584573.mp3:
# Failed to process common_voice_en_48122.mp3:
# Failed to process common_voice_en_589708.mp3:
# Failed to process common_voice_en_479275.mp3:
# Failed to process common_voice_en_578702.mp3:
# Failed to process common_voice_en_498901.mp3:
# Failed to process common_voice_en_400365.mp3:
# Failed to process common_voice_en_528565.mp3:
# Failed to process common_voice_en_684523.mp3:
# Failed to process common_voice_en_499712.mp3:
# Failed to process common_voice_en_73698.mp3:
# Failed to process common_voice_en_538112.mp3:
# Failed to process common_voice_en_6215470.mp3:
# Failed to process common_voice_en_621800.mp3:
# Failed to process common_voice_en_73527.mp3:
# Failed to process common_voice_en_571060.mp3:
# Failed to process common_voice_en_597685.mp3:
# Failed to process common_voice_en_533672.mp3:
# Failed to process common_voice_en_38180.mp3:
# Failed to process common_voice_en_547572.mp3:
# Failed to process common_voice_en_566120.mp3:
# Failed to process common_voice_en_667158.mp3:
# Failed to process common_voice_en_589744.mp3:
# Failed to process common_voice_en_77592.mp3:
# Failed to process common_voice_en_667280.mp3:
# Failed to process common_voice_en_546119.mp3:
# Failed to process common_voice_en_84257.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_84257.mp3'
# Failed to process common_voice_en_4404456.mp3:
# Failed to process common_voice_en_668036.mp3:
# Failed to process common_voice_en_84498.mp3:
# Failed to process common_voice_en_639263.mp3:
# Failed to process common_voice_en_80541.mp3:
# Failed to process common_voice_en_68751.mp3:
# Failed to process common_voice_en_19724850.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19724850.mp3'
# Failed to process common_voice_en_7646746.mp3:
# Failed to process common_voice_en_18835378.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18835378.mp3'
# Failed to process common_voice_en_464689.mp3:
# Failed to process common_voice_en_678227.mp3:
# Failed to process common_voice_en_36945.mp3:
# Failed to process common_voice_en_71619.mp3:
# Failed to process common_voice_en_681511.mp3:
# Failed to process common_voice_en_129462.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_129462.mp3'
# Failed to process common_voice_en_92053.mp3:
# Failed to process common_voice_en_548084.mp3:
# Failed to process common_voice_en_574006.mp3:
# Failed to process common_voice_en_18120081.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18120081.mp3'
# Failed to process common_voice_en_577890.mp3:
# Failed to process common_voice_en_559952.mp3:
# Failed to process common_voice_en_523114.mp3:
# Failed to process common_voice_en_99539.mp3:
# Failed to process common_voice_en_85943.mp3:
# Failed to process common_voice_en_484252.mp3:
# Failed to process common_voice_en_4607482.mp3:
# Failed to process common_voice_en_673882.mp3:
# Failed to process common_voice_en_84292.mp3:
# Failed to process common_voice_en_592297.mp3:
# Failed to process common_voice_en_667270.mp3:
# Failed to process common_voice_en_533391.mp3:
# Failed to process common_voice_en_18034035.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18034035.mp3'
# Failed to process common_voice_en_18606739.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18606739.mp3'
# Failed to process common_voice_en_92530.mp3:
# Failed to process common_voice_en_60390.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_60390.mp3'
# Failed to process common_voice_en_552086.mp3:
# Failed to process common_voice_en_19199088.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19199088.mp3'
# Failed to process common_voice_en_523092.mp3:
# Failed to process common_voice_en_585518.mp3:
# Failed to process common_voice_en_495738.mp3:
# Failed to process common_voice_en_512500.mp3:
# Failed to process common_voice_en_9315.mp3: Failed to process common_voice_en_53190.mp3:
#
# Failed to process common_voice_en_619768.mp3:
# Failed to process common_voice_en_472645.mp3:
# Failed to process common_voice_en_597082.mp3:
# Failed to process common_voice_en_90007.mp3:
# Failed to process common_voice_en_574712.mp3:
# Failed to process common_voice_en_648264.mp3:
# Failed to process common_voice_en_59842.mp3:
# Failed to process common_voice_en_675009.mp3:
# Failed to process common_voice_en_543918.mp3:
# Failed to process common_voice_en_508995.mp3:
# Failed to process common_voice_en_64736.mp3:
# Failed to process common_voice_en_116458.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_116458.mp3'
# Failed to process common_voice_en_668882.mp3:
# Failed to process common_voice_en_59949.mp3:
# Failed to process common_voice_en_512037.mp3:
# Failed to process common_voice_en_529656.mp3:
# Failed to process common_voice_en_597302.mp3:
# Failed to process common_voice_en_642529.mp3:
# Failed to process common_voice_en_517930.mp3:
# Failed to process common_voice_en_505171.mp3:
# Failed to process common_voice_en_38193.mp3:
# Failed to process common_voice_en_17725919.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17725919.mp3'
# Failed to process common_voice_en_19047345.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19047345.mp3'
# Failed to process common_voice_en_38866.mp3:
# Failed to process common_voice_en_65282.mp3:
# Failed to process common_voice_en_79586.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_79586.mp3'
# Failed to process common_voice_en_37807.mp3:
# Failed to process common_voice_en_615864.mp3:
# Failed to process common_voice_en_520171.mp3:
# Failed to process common_voice_en_589604.mp3:
# Failed to process common_voice_en_17329285.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17329285.mp3'
# Failed to process common_voice_en_59780.mp3:
# Failed to process common_voice_en_567564.mp3:
# Failed to process common_voice_en_608575.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_608575.mp3'
# Failed to process common_voice_en_547139.mp3:
# Failed to process common_voice_en_19805845.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19805845.mp3'
# Failed to process common_voice_en_670369.mp3:
# Failed to process common_voice_en_541306.mp3:
# Failed to process common_voice_en_599233.mp3:
# Failed to process common_voice_en_597021.mp3:
# Failed to process common_voice_en_520047.mp3:
# Failed to process common_voice_en_674943.mp3:
# Failed to process common_voice_en_478616.mp3:
# Failed to process common_voice_en_146991.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_146991.mp3'
# Failed to process common_voice_en_48471.mp3:
# Failed to process common_voice_en_92528.mp3:
# Failed to process common_voice_en_597406.mp3:
# Failed to process common_voice_en_604548.mp3:
# Failed to process common_voice_en_595371.mp3:
# Failed to process common_voice_en_472703.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_472703.mp3'
# Failed to process common_voice_en_667395.mp3:
# Failed to process common_voice_en_69539.mp3:
# Failed to process common_voice_en_519971.mp3:
# Failed to process common_voice_en_639163.mp3:
# Failed to process common_voice_en_542941.mp3:
# Failed to process common_voice_en_444289.mp3:
# Failed to process common_voice_en_663586.mp3:
# Failed to process common_voice_en_584833.mp3:
# Failed to process common_voice_en_5429637.mp3:
# Failed to process common_voice_en_59904.mp3:
# Failed to process common_voice_en_537666.mp3:
# Failed to process common_voice_en_646651.mp3:
# Failed to process common_voice_en_69058.mp3:
# Failed to process common_voice_en_39047.mp3:
# Failed to process common_voice_en_486854.mp3:
# Failed to process common_voice_en_646681.mp3:
# Failed to process common_voice_en_668587.mp3:
# Failed to process common_voice_en_528579.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_528579.mp3'
# Failed to process common_voice_en_589832.mp3:
# Failed to process common_voice_en_63791.mp3:
# Failed to process common_voice_en_668887.mp3:
# Failed to process common_voice_en_59992.mp3:
# Failed to process common_voice_en_549555.mp3:
# Failed to process common_voice_en_543090.mp3:
# Failed to process common_voice_en_39882.mp3:
# Failed to process common_voice_en_73608.mp3:
# Failed to process common_voice_en_18844673.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18844673.mp3'
# Failed to process common_voice_en_18666321.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18666321.mp3'
# Failed to process common_voice_en_605051.mp3:
# Failed to process common_voice_en_614040.mp3:
# Failed to process common_voice_en_523062.mp3:
# Failed to process common_voice_en_523184.mp3:
# Failed to process common_voice_en_17390136.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17390136.mp3'
# Failed to process common_voice_en_96341.mp3:
# Failed to process common_voice_en_84255.mp3:
# Failed to process common_voice_en_78761.mp3:
# Failed to process common_voice_en_668379.mp3:
# Failed to process common_voice_en_649150.mp3:
# Failed to process common_voice_en_18985949.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18985949.mp3'
# Failed to process common_voice_en_597577.mp3:
# Failed to process common_voice_en_644855.mp3:
# Failed to process common_voice_en_18075301.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18075301.mp3'
# Failed to process common_voice_en_19179507.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19179507.mp3'
# Failed to process common_voice_en_543439.mp3:
# Failed to process common_voice_en_39048.mp3:
# Failed to process common_voice_en_19476385.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19476385.mp3'
# Failed to process common_voice_en_612019.mp3:
# Failed to process common_voice_en_18334539.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18334539.mp3'
# Failed to process common_voice_en_612269.mp3:
# Failed to process common_voice_en_74897.mp3:
# Failed to process common_voice_en_73547.mp3:
# Failed to process common_voice_en_74978.mp3:
# Failed to process common_voice_en_484519.mp3:
# Failed to process common_voice_en_630854.mp3:
# Failed to process common_voice_en_532092.mp3:
# Failed to process common_voice_en_18534565.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18534565.mp3'
# Failed to process common_voice_en_668167.mp3:
# Failed to process common_voice_en_90906.mp3:
# Failed to process common_voice_en_672179.mp3:
# Failed to process common_voice_en_671722.mp3:
# Failed to process common_voice_en_540759.mp3:
# Failed to process common_voice_en_496900.mp3:
# Failed to process common_voice_en_375583.mp3:
# Failed to process common_voice_en_547711.mp3:
# Failed to process common_voice_en_499709.mp3:
# Failed to process common_voice_en_597027.mp3:
# Failed to process common_voice_en_674963.mp3:
# Failed to process common_voice_en_575107.mp3:
# Failed to process common_voice_en_54784.mp3:
# Failed to process common_voice_en_521579.mp3:
# Failed to process common_voice_en_8603412.mp3:
# Failed to process common_voice_en_624318.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_624318.mp3'
# Failed to process common_voice_en_38066.mp3:
# Failed to process common_voice_en_638512.mp3:
# Failed to process common_voice_en_541308.mp3:
# Failed to process common_voice_en_496498.mp3:
# Failed to process common_voice_en_613358.mp3:
# Failed to process common_voice_en_78794.mp3:
# Failed to process common_voice_en_625413.mp3:
# Failed to process common_voice_en_510521.mp3:
# Failed to process common_voice_en_642429.mp3:
# Failed to process common_voice_en_41442.mp3:
# Failed to process common_voice_en_598813.mp3:
# Failed to process common_voice_en_92228.mp3:
# Failed to process common_voice_en_595452.mp3:
# Failed to process common_voice_en_375590.mp3:
# Failed to process common_voice_en_64086.mp3:
# Failed to process common_voice_en_41489.mp3:
# Failed to process common_voice_en_613230.mp3:
# Failed to process common_voice_en_472656.mp3:
# Failed to process common_voice_en_644309.mp3:
# Failed to process common_voice_en_639078.mp3:
# Failed to process common_voice_en_565281.mp3:
# Failed to process common_voice_en_657517.mp3:
# Failed to process common_voice_en_528453.mp3:
# Failed to process common_voice_en_499484.mp3:
# Failed to process common_voice_en_516573.mp3:
# Failed to process common_voice_en_671992.mp3:
# Failed to process common_voice_en_67605.mp3:
# Failed to process common_voice_en_69216.mp3:
# Failed to process common_voice_en_588095.mp3:
# Failed to process common_voice_en_615623.mp3:
# Failed to process common_voice_en_73552.mp3:
# Failed to process common_voice_en_413120.mp3:
# Failed to process common_voice_en_564864.mp3:
# Failed to process common_voice_en_620649.mp3:
# Failed to process common_voice_en_634046.mp3:
# Failed to process common_voice_en_547057.mp3:
# Failed to process common_voice_en_543839.mp3:
# Failed to process common_voice_en_668127.mp3:
# Failed to process common_voice_en_18658357.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18658357.mp3'
# Failed to process common_voice_en_41177.mp3:
# Failed to process common_voice_en_69034.mp3:
# Failed to process common_voice_en_497091.mp3:
# Failed to process common_voice_en_17252687.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17252687.mp3'
# Failed to process common_voice_en_489294.mp3:
# Failed to process common_voice_en_668153.mp3:
# Failed to process common_voice_en_495929.mp3:
# Failed to process common_voice_en_595866.mp3:
# Failed to process common_voice_en_672195.mp3:
# Failed to process common_voice_en_146148.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_146148.mp3'
# Failed to process common_voice_en_548137.mp3:
# Failed to process common_voice_en_49891.mp3:
# Failed to process common_voice_en_642425.mp3:
# Failed to process common_voice_en_72653.mp3:
# Failed to process common_voice_en_639069.mp3:
# Failed to process common_voice_en_13759.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_13759.mp3'
# Failed to process common_voice_en_511577.mp3:
# Failed to process common_voice_en_661344.mp3:
# Failed to process common_voice_en_967984.mp3:
# Failed to process common_voice_en_9301.mp3:
# Failed to process common_voice_en_548409.mp3:
# Failed to process common_voice_en_551834.mp3:
# Failed to process common_voice_en_553427.mp3:
# Failed to process common_voice_en_83869.mp3:
# Failed to process common_voice_en_643352.mp3:
# Failed to process common_voice_en_499999.mp3:
# Failed to process common_voice_en_18125790.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18125790.mp3'
# Failed to process common_voice_en_5723068.mp3:
# Failed to process common_voice_en_672664.mp3:
# Failed to process common_voice_en_639347.mp3:
# Failed to process common_voice_en_660155.mp3:
# Failed to process common_voice_en_560431.mp3:
# Failed to process common_voice_en_614551.mp3:
# Failed to process common_voice_en_73777.mp3:
# Failed to process common_voice_en_96576.mp3:
# Failed to process common_voice_en_574666.mp3:
# Failed to process common_voice_en_668245.mp3:
# Failed to process common_voice_en_97728.mp3:
# Failed to process common_voice_en_60908.mp3:
# Failed to process common_voice_en_553496.mp3:
# Failed to process common_voice_en_664689.mp3:
# Failed to process common_voice_en_646367.mp3:
# Failed to process common_voice_en_499068.mp3:
# Failed to process common_voice_en_18405224.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18405224.mp3'
# Failed to process common_voice_en_388601.mp3:
# Failed to process common_voice_en_497828.mp3:
# Failed to process common_voice_en_437334.mp3:
# Failed to process common_voice_en_47461.mp3:
# Failed to process common_voice_en_614576.mp3:
# Failed to process common_voice_en_65281.mp3:
# Failed to process common_voice_en_657528.mp3:
# Failed to process common_voice_en_551840.mp3:
# Failed to process common_voice_en_519902.mp3:
# Failed to process common_voice_en_19311905.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19311905.mp3'
# Failed to process common_voice_en_523323.mp3:
# Failed to process common_voice_en_603322.mp3:
# Failed to process common_voice_en_517785.mp3:
# Failed to process common_voice_en_673662.mp3:
# Failed to process common_voice_en_683312.mp3:
# Failed to process common_voice_en_5170465.mp3:
# Failed to process common_voice_en_499255.mp3:
# Failed to process common_voice_en_575111.mp3:
# Failed to process common_voice_en_116665.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_116665.mp3'
# Failed to process common_voice_en_650116.mp3:
# Failed to process common_voice_en_38268.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_38268.mp3'
# Failed to process common_voice_en_547290.mp3:
# Failed to process common_voice_en_612873.mp3:
# Failed to process common_voice_en_523285.mp3:
# Failed to process common_voice_en_60037.mp3:
# Failed to process common_voice_en_97729.mp3:
# Failed to process common_voice_en_533579.mp3:
# Failed to process common_voice_en_486832.mp3:
# Failed to process common_voice_en_690333.mp3:
# Failed to process common_voice_en_547235.mp3:
# Failed to process common_voice_en_614247.mp3:
# Failed to process common_voice_en_621858.mp3:
# Failed to process common_voice_en_528431.mp3:
# Failed to process common_voice_en_589735.mp3:
# Failed to process common_voice_en_644323.mp3:
# Failed to process common_voice_en_584612.mp3:
# Failed to process common_voice_en_60008.mp3:
# Failed to process common_voice_en_567410.mp3:
# Failed to process common_voice_en_508805.mp3:
# Failed to process common_voice_en_603765.mp3:
# Failed to process common_voice_en_674921.mp3:
# Failed to process common_voice_en_18857787.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18857787.mp3'
# Failed to process common_voice_en_529017.mp3:
# Failed to process common_voice_en_598104.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_598104.mp3'
# Failed to process common_voice_en_547587.mp3:
# Failed to process common_voice_en_65153.mp3:
# Failed to process common_voice_en_60005.mp3:
# Failed to process common_voice_en_561879.mp3:
# Failed to process common_voice_en_446498.mp3:
# Failed to process common_voice_en_516606.mp3:
# Failed to process common_voice_en_636755.mp3:
# Failed to process common_voice_en_544239.mp3:
# Failed to process common_voice_en_23549.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_23549.mp3'
# Failed to process common_voice_en_9354.mp3:
# Failed to process common_voice_en_91910.mp3:
# Failed to process common_voice_en_547620.mp3:
# Failed to process common_voice_en_566767.mp3:
# Failed to process common_voice_en_671774.mp3:
# Failed to process common_voice_en_499205.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_499205.mp3'
# Failed to process common_voice_en_529063.mp3:
# Failed to process common_voice_en_543431.mp3:
# Failed to process common_voice_en_400375.mp3:
# Failed to process common_voice_en_17411583.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17411583.mp3'
# Failed to process common_voice_en_514980.mp3:
# Failed to process common_voice_en_18639649.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18639649.mp3'
# Failed to process common_voice_en_624161.mp3:
# Failed to process common_voice_en_583676.mp3:
# Failed to process common_voice_en_78689.mp3:
# Failed to process common_voice_en_92004.mp3:
# Failed to process common_voice_en_587184.mp3:
# Failed to process common_voice_en_625430.mp3:
# Failed to process common_voice_en_43173.mp3:
# Failed to process common_voice_en_38093.mp3:
# Failed to process common_voice_en_44716.mp3:
# Failed to process common_voice_en_676869.mp3:
# Failed to process common_voice_en_573997.mp3:
# Failed to process common_voice_en_649160.mp3:
# Failed to process common_voice_en_673944.mp3:
# Failed to process common_voice_en_499107.mp3:
# Failed to process common_voice_en_674942.mp3:
# Failed to process common_voice_en_16016735.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_16016735.mp3'
# Failed to process common_voice_en_624151.mp3:
# Failed to process common_voice_en_575987.mp3:
# Failed to process common_voice_en_694136.mp3:
# Failed to process common_voice_en_83762.mp3:
# Failed to process common_voice_en_4029334.mp3:
# Failed to process common_voice_en_602984.mp3:
# Failed to process common_voice_en_17279300.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17279300.mp3'
# Failed to process common_voice_en_642409.mp3:
# Failed to process common_voice_en_651659.mp3:
# Failed to process common_voice_en_657566.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_657566.mp3'
# Failed to process common_voice_en_599247.mp3:
# Failed to process common_voice_en_628617.mp3:
# Failed to process common_voice_en_547505.mp3:
# Failed to process common_voice_en_672302.mp3:
# Failed to process common_voice_en_38214.mp3:
# Failed to process common_voice_en_483476.mp3:
# Failed to process common_voice_en_74562.mp3:
# Failed to process common_voice_en_564742.mp3:
# Failed to process common_voice_en_496518.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_496518.mp3'
# Failed to process common_voice_en_614240.mp3:
# Failed to process common_voice_en_668214.mp3:
# Failed to process common_voice_en_660658.mp3:
# Failed to process common_voice_en_18935140.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18935140.mp3'
# Failed to process common_voice_en_9306.mp3:
# Failed to process common_voice_en_18658800.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18658800.mp3'
# Failed to process common_voice_en_392521.mp3:
# Failed to process common_voice_en_547899.mp3:
# Failed to process common_voice_en_672656.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_672656.mp3'
# Failed to process common_voice_en_598152.mp3:
# Failed to process common_voice_en_59690.mp3:
# Failed to process common_voice_en_18985761.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18985761.mp3'
# Failed to process common_voice_en_547978.mp3:
# Failed to process common_voice_en_65257.mp3:
# Failed to process common_voice_en_665506.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_665506.mp3'
# Failed to process common_voice_en_547416.mp3:
# Failed to process common_voice_en_91959.mp3:
# Failed to process common_voice_en_153138.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_153138.mp3'
# Failed to process common_voice_en_523083.mp3:
# Failed to process common_voice_en_678911.mp3:
# Failed to process common_voice_en_486120.mp3:
# Failed to process common_voice_en_694431.mp3:
# Failed to process common_voice_en_41550.mp3:
# Failed to process common_voice_en_573894.mp3:
# Failed to process common_voice_en_413107.mp3:
# Failed to process common_voice_en_90076.mp3:
# Failed to process common_voice_en_499332.mp3:
# Failed to process common_voice_en_575108.mp3:
# Failed to process common_voice_en_597256.mp3:
# Failed to process common_voice_en_668498.mp3:
# Failed to process common_voice_en_625444.mp3:
# Failed to process common_voice_en_631939.mp3:
# Failed to process common_voice_en_588100.mp3:
# Failed to process common_voice_en_529041.mp3:
# Failed to process common_voice_en_74833.mp3:
# Failed to process common_voice_en_17260975.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17260975.mp3'
# Failed to process common_voice_en_541286.mp3:
# Failed to process common_voice_en_563833.mp3:
# Failed to process common_voice_en_507770.mp3:
# Failed to process common_voice_en_625215.mp3:
# Failed to process common_voice_en_569538.mp3:
# Failed to process common_voice_en_17731366.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17731366.mp3'
# Failed to process common_voice_en_18097957.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18097957.mp3'
# Failed to process common_voice_en_597035.mp3:
# Failed to process common_voice_en_674979.mp3:
# Failed to process common_voice_en_532120.mp3:
# Failed to process common_voice_en_566764.mp3:
# Failed to process common_voice_en_671996.mp3:
# Failed to process common_voice_en_627829.mp3:
# Failed to process common_voice_en_523339.mp3:
# Failed to process common_voice_en_533695.mp3:
# Failed to process common_voice_en_542940.mp3:
# Failed to process common_voice_en_18655445.mp3: mean requires at least one data point
# Failed to process common_voice_en_532920.mp3:
# Failed to process common_voice_en_618231.mp3:
# Failed to process common_voice_en_18767379.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18767379.mp3'
# Failed to process common_voice_en_615194.mp3:
# Failed to process common_voice_en_18332237.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18332237.mp3'
# Failed to process common_voice_en_675002.mp3:
# Failed to process common_voice_en_613378.mp3:
# Failed to process common_voice_en_18985473.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18985473.mp3'
# Failed to process common_voice_en_563854.mp3:
# Failed to process common_voice_en_639264.mp3:
# Failed to process common_voice_en_55532.mp3:
# Failed to process common_voice_en_627803.mp3:
# Failed to process common_voice_en_504682.mp3:
# Failed to process common_voice_en_546860.mp3:
# Failed to process common_voice_en_138090.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_138090.mp3'
# Failed to process common_voice_en_48495.mp3:
# Failed to process common_voice_en_504466.mp3:
# Failed to process common_voice_en_666911.mp3:
# Failed to process common_voice_en_4237214.mp3:
# Failed to process common_voice_en_18424092.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18424092.mp3'
# Failed to process common_voice_en_73595.mp3:
# Failed to process common_voice_en_17347991.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17347991.mp3'
# Failed to process common_voice_en_547427.mp3:
# Failed to process common_voice_en_400352.mp3:
# Failed to process common_voice_en_486063.mp3:
# Failed to process common_voice_en_507777.mp3:
# Failed to process common_voice_en_623082.mp3:
# Failed to process common_voice_en_605152.mp3:
# Failed to process common_voice_en_17808712.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17808712.mp3'
# Failed to process common_voice_en_547820.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_547820.mp3'
# Failed to process common_voice_en_49946.mp3:
# Failed to process common_voice_en_584610.mp3:
# Failed to process common_voice_en_614357.mp3:
# Failed to process common_voice_en_547959.mp3:
# Failed to process common_voice_en_567551.mp3:
# Failed to process common_voice_en_597419.mp3:
# Failed to process common_voice_en_5538600.mp3:
# Failed to process common_voice_en_497761.mp3:
# Failed to process common_voice_en_17551173.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17551173.mp3'
# Failed to process common_voice_en_84399.mp3:
# Failed to process common_voice_en_528471.mp3:
# Failed to process common_voice_en_437661.mp3:
# Failed to process common_voice_en_41449.mp3:
# Failed to process common_voice_en_564760.mp3:
# Failed to process common_voice_en_628442.mp3:
# Failed to process common_voice_en_66286.mp3:
# Failed to process common_voice_en_91271.mp3:
# Failed to process common_voice_en_663638.mp3:
# Failed to process common_voice_en_596208.mp3:
# Failed to process common_voice_en_616030.mp3:
# Failed to process common_voice_en_673888.mp3:
# Failed to process common_voice_en_8731596.mp3:
# Failed to process common_voice_en_496479.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_496479.mp3'
# Failed to process common_voice_en_511816.mp3:
# Failed to process common_voice_en_547159.mp3:
# Failed to process common_voice_en_668133.mp3:
# Failed to process common_voice_en_580454.mp3:
# Failed to process common_voice_en_547687.mp3:
# Failed to process common_voice_en_69654.mp3:
# Failed to process common_voice_en_684140.mp3:
# Failed to process common_voice_en_66668.mp3:
# Failed to process common_voice_en_8556768.mp3:
# Failed to process common_voice_en_557118.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_557118.mp3'
# Failed to process common_voice_en_89488.mp3:
# Failed to process common_voice_en_478092.mp3:
# Failed to process common_voice_en_477996.mp3:
# Failed to process common_voice_en_612058.mp3:
# Failed to process common_voice_en_512030.mp3:
# Failed to process common_voice_en_570685.mp3:
# Failed to process common_voice_en_587144.mp3:
# Failed to process common_voice_en_69690.mp3:
# Failed to process common_voice_en_700071.mp3:
# Failed to process common_voice_en_18878733.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18878733.mp3'
# Failed to process common_voice_en_497747.mp3:
# Failed to process common_voice_en_528583.mp3:
# Failed to process common_voice_en_430088.mp3:
# Failed to process common_voice_en_671903.mp3:
# Failed to process common_voice_en_41454.mp3:
# Failed to process common_voice_en_392568.mp3:
# Failed to process common_voice_en_518337.mp3:
# Failed to process common_voice_en_627114.mp3:
# Failed to process common_voice_en_570654.mp3:
# Failed to process common_voice_en_628379.mp3:
# Failed to process common_voice_en_519851.mp3:
# Failed to process common_voice_en_17266617.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17266617.mp3'
# Failed to process common_voice_en_543466.mp3:
# Failed to process common_voice_en_494528.mp3:
# Failed to process common_voice_en_493597.mp3:
# Failed to process common_voice_en_499794.mp3:
# Failed to process common_voice_en_511722.mp3:
# Failed to process common_voice_en_98855.mp3:
# Failed to process common_voice_en_561358.mp3:
# Failed to process common_voice_en_1237112.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_1237112.mp3'
# Failed to process common_voice_en_4168700.mp3:
# Failed to process common_voice_en_547909.mp3:
# Failed to process common_voice_en_543496.mp3:
# Failed to process common_voice_en_666893.mp3:
# Failed to process common_voice_en_18489852.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18489852.mp3'
# Failed to process common_voice_en_484489.mp3:
# Failed to process common_voice_en_48500.mp3:
# Failed to process common_voice_en_546841.mp3:
# Failed to process common_voice_en_596764.mp3:
# Failed to process common_voice_en_613195.mp3:
# Failed to process common_voice_en_19374212.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19374212.mp3'
# Failed to process common_voice_en_615865.mp3:
# Failed to process common_voice_en_614068.mp3:
# Failed to process common_voice_en_17731346.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17731346.mp3'
# Failed to process common_voice_en_636732.mp3:
# Failed to process common_voice_en_612200.mp3:
# Failed to process common_voice_en_690327.mp3:
# Failed to process common_voice_en_212991.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_212991.mp3'
# Failed to process common_voice_en_598051.mp3:
# Failed to process common_voice_en_523320.mp3:
# Failed to process common_voice_en_505166.mp3:
# Failed to process common_voice_en_73599.mp3:
# Failed to process common_voice_en_592133.mp3:
# Failed to process common_voice_en_549573.mp3:
# Failed to process common_voice_en_529071.mp3:
# Failed to process common_voice_en_672091.mp3:
# Failed to process common_voice_en_614637.mp3:
# Failed to process common_voice_en_18432326.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18432326.mp3'
# Failed to process common_voice_en_547462.mp3:
# Failed to process common_voice_en_38105.mp3:
# Failed to process common_voice_en_484128.mp3:
# Failed to process common_voice_en_64064.mp3:
# Failed to process common_voice_en_469936.mp3:
# Failed to process common_voice_en_566143.mp3:
# Failed to process common_voice_en_542952.mp3:
# Failed to process common_voice_en_542968.mp3:
# Failed to process common_voice_en_557604.mp3:
# Failed to process common_voice_en_486905.mp3:
# Failed to process common_voice_en_656434.mp3: Failed to process common_voice_en_668588.mp3:
#
# Failed to process common_voice_en_650305.mp3:
# Failed to process common_voice_en_77673.mp3:
# Failed to process common_voice_en_47449.mp3:
# Failed to process common_voice_en_517964.mp3:
# Failed to process common_voice_en_543981.mp3:
# Failed to process common_voice_en_543775.mp3:
# Failed to process common_voice_en_583234.mp3:
# Failed to process common_voice_en_19678598.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19678598.mp3'
# Failed to process common_voice_en_85142.mp3:
# Failed to process common_voice_en_218330.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_218330.mp3'
# Failed to process common_voice_en_644104.mp3:
# Failed to process common_voice_en_84228.mp3:
# Failed to process common_voice_en_612914.mp3:
# Failed to process common_voice_en_676856.mp3:
# Failed to process common_voice_en_668485.mp3:
# Failed to process common_voice_en_90066.mp3:
# Failed to process common_voice_en_218038.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_218038.mp3'
# Failed to process common_voice_en_684205.mp3:
# Failed to process common_voice_en_553198.mp3:
# Failed to process common_voice_en_639184.mp3:
# Failed to process common_voice_en_55867.mp3:
# Failed to process common_voice_en_60448.mp3:
# Failed to process common_voice_en_668027.mp3:
# Failed to process common_voice_en_47409.mp3:
# Failed to process common_voice_en_561866.mp3:
# Failed to process common_voice_en_18080527.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18080527.mp3'
# Failed to process common_voice_en_502957.mp3:
# Failed to process common_voice_en_4607438.mp3:
# Failed to process common_voice_en_496490.mp3:
# Failed to process common_voice_en_669871.mp3:
# Failed to process common_voice_en_20099859.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_20099859.mp3'
# Failed to process common_voice_en_511664.mp3:
# Failed to process common_voice_en_464623.mp3:
# Failed to process common_voice_en_498538.mp3:
# Failed to process common_voice_en_478754.mp3:
# Failed to process common_voice_en_554113.mp3:
# Failed to process common_voice_en_584707.mp3:
# Failed to process common_voice_en_696199.mp3:
# Failed to process common_voice_en_604938.mp3:
# Failed to process common_voice_en_533722.mp3:
# Failed to process common_voice_en_41634.mp3:
# Failed to process common_voice_en_8857962.mp3:
# Failed to process common_voice_en_673751.mp3:
# Failed to process common_voice_en_18852054.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18852054.mp3'
# Failed to process common_voice_en_41577.mp3:
# Failed to process common_voice_en_597671.mp3:
# Failed to process common_voice_en_522174.mp3:
# Failed to process common_voice_en_137937.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_137937.mp3'
# Failed to process common_voice_en_499340.mp3:
# Failed to process common_voice_en_532936.mp3:
# Failed to process common_voice_en_18564361.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18564361.mp3'
# Failed to process common_voice_en_625202.mp3:
# Failed to process common_voice_en_613339.mp3:
# Failed to process common_voice_en_573869.mp3:
# Failed to process common_voice_en_59880.mp3:
# Failed to process common_voice_en_596999.mp3:
# Failed to process common_voice_en_521630.mp3:
# Failed to process common_voice_en_584644.mp3:
# Failed to process common_voice_en_691873.mp3:
# Failed to process common_voice_en_565469.mp3:
# Failed to process common_voice_en_5429652.mp3:
# Failed to process common_voice_en_668418.mp3:
# Failed to process common_voice_en_563056.mp3:
# Failed to process common_voice_en_625325.mp3:
# Failed to process common_voice_en_608406.mp3:
# Failed to process common_voice_en_548044.mp3:
# Failed to process common_voice_en_534211.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_534211.mp3'
# Failed to process common_voice_en_612879.mp3:
# Failed to process common_voice_en_541255.mp3:
# Failed to process common_voice_en_84327.mp3:
# Failed to process common_voice_en_615861.mp3:
# Failed to process common_voice_en_499080.mp3:
# Failed to process common_voice_en_49586.mp3:
# Failed to process common_voice_en_514774.mp3:
# Failed to process common_voice_en_557126.mp3:
# Failed to process common_voice_en_520222.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_520222.mp3'
# Failed to process common_voice_en_85881.mp3:
# Failed to process common_voice_en_666208.mp3:
# Failed to process common_voice_en_99594.mp3:
# Failed to process common_voice_en_74796.mp3:
# Failed to process common_voice_en_547164.mp3:
# Failed to process common_voice_en_400362.mp3:
# Failed to process common_voice_en_6932942.mp3:
# Failed to process common_voice_en_513702.mp3:
# Failed to process common_voice_en_544226.mp3:
# Failed to process common_voice_en_18121538.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18121538.mp3'
# Failed to process common_voice_en_17530062.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17530062.mp3'
# Failed to process common_voice_en_512516.mp3:
# Failed to process common_voice_en_500885.mp3:
# Failed to process common_voice_en_674966.mp3:
# Failed to process common_voice_en_38200.mp3:
# Failed to process common_voice_en_598614.mp3:
# Failed to process common_voice_en_511733.mp3:
# Failed to process common_voice_en_464680.mp3:
# Failed to process common_voice_en_616511.mp3:
# Failed to process common_voice_en_597451.mp3:
# Failed to process common_voice_en_546893.mp3:
# Failed to process common_voice_en_499765.mp3:
# Failed to process common_voice_en_691461.mp3:
# Failed to process common_voice_en_625144.mp3:
# Failed to process common_voice_en_96299.mp3:
# Failed to process common_voice_en_577869.mp3:
# Failed to process common_voice_en_528322.mp3:
# Failed to process common_voice_en_546970.mp3:
# Failed to process common_voice_en_199370.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_199370.mp3'
# Failed to process common_voice_en_604049.mp3:
# Failed to process common_voice_en_64077.mp3:
# Failed to process common_voice_en_478776.mp3:
# Failed to process common_voice_en_672200.mp3:
# Failed to process common_voice_en_584730.mp3:
# Failed to process common_voice_en_19002917.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19002917.mp3'
# Failed to process common_voice_en_60894.mp3:
# Failed to process common_voice_en_555759.mp3:
# Failed to process common_voice_en_630863.mp3:
# Failed to process common_voice_en_38329.mp3:
# Failed to process common_voice_en_597515.mp3:
# Failed to process common_voice_en_517171.mp3:
# Failed to process common_voice_en_518341.mp3:
# Failed to process common_voice_en_611623.mp3:
# Failed to process common_voice_en_49960.mp3:
# Failed to process common_voice_en_4096834.mp3:
# Failed to process common_voice_en_59793.mp3:
# Failed to process common_voice_en_532117.mp3:
# Failed to process common_voice_en_446268.mp3:
# Failed to process common_voice_en_535668.mp3:
# Failed to process common_voice_en_17926597.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17926597.mp3'
# Failed to process common_voice_en_373491.mp3:
# Failed to process common_voice_en_567172.mp3:
# Failed to process common_voice_en_83831.mp3:
# Failed to process common_voice_en_563821.mp3:
# Failed to process common_voice_en_508842.mp3:
# Failed to process common_voice_en_683330.mp3:
# Failed to process common_voice_en_627108.mp3:
# Failed to process common_voice_en_41497.mp3:
# Failed to process common_voice_en_84506.mp3:
# Failed to process common_voice_en_388287.mp3:
# Failed to process common_voice_en_499133.mp3:
# Failed to process common_voice_en_511575.mp3:
# Failed to process common_voice_en_533023.mp3:
# Failed to process common_voice_en_495282.mp3:
# Failed to process common_voice_en_556958.mp3:
# Failed to process common_voice_en_499839.mp3:
# Failed to process common_voice_en_482654.mp3:
# Failed to process common_voice_en_547674.mp3:
# Failed to process common_voice_en_478782.mp3:
# Failed to process common_voice_en_69036.mp3:
# Failed to process common_voice_en_571545.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_571545.mp3'
# Failed to process common_voice_en_543463.mp3:
# Failed to process common_voice_en_43095.mp3:
# Failed to process common_voice_en_677072.mp3:
# Failed to process common_voice_en_514981.mp3:
# Failed to process common_voice_en_532114.mp3:
# Failed to process common_voice_en_69106.mp3:
# Failed to process common_voice_en_480089.mp3:
# Failed to process common_voice_en_812.mp3:
# Failed to process common_voice_en_20092327.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_20092327.mp3'
# Failed to process common_voice_en_499845.mp3:
# Failed to process common_voice_en_684179.mp3:
# Failed to process common_voice_en_612712.mp3:
# Failed to process common_voice_en_608521.mp3:
# Failed to process common_voice_en_19813501.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19813501.mp3'
# Failed to process common_voice_en_547138.mp3:
# Failed to process common_voice_en_676859.mp3:
# Failed to process common_voice_en_547712.mp3:
# Failed to process common_voice_en_19072437.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19072437.mp3'
# Failed to process common_voice_en_543065.mp3:
# Failed to process common_voice_en_4168733.mp3:
# Failed to process common_voice_en_496477.mp3:
# Failed to process common_voice_en_18034053.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18034053.mp3'
# Failed to process common_voice_en_450716.mp3:
# Failed to process common_voice_en_512515.mp3:
# Failed to process common_voice_en_73534.mp3:
# Failed to process common_voice_en_544082.mp3:
# Failed to process common_voice_en_653887.mp3:
# Failed to process common_voice_en_74637.mp3:
# Failed to process common_voice_en_449936.mp3:
# Failed to process common_voice_en_627835.mp3:
# Failed to process common_voice_en_577903.mp3:
# Failed to process common_voice_en_17286679.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_17286679.mp3'
# Failed to process common_voice_en_513683.mp3:
# Failed to process common_voice_en_548092.mp3:
# Failed to process common_voice_en_97614.mp3:
# Failed to process common_voice_en_18446704.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18446704.mp3'
# Failed to process common_voice_en_505170.mp3:
# Failed to process common_voice_en_608555.mp3:
# Failed to process common_voice_en_563252.mp3:
# Failed to process common_voice_en_547177.mp3:
# Failed to process common_voice_en_543833.mp3:
# Failed to process common_voice_en_149065.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_149065.mp3'
# Failed to process common_voice_en_19972875.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19972875.mp3'
# Failed to process common_voice_en_597065.mp3:
# Failed to process common_voice_en_375596.mp3:
# Failed to process common_voice_en_546948.mp3:
# Failed to process common_voice_en_75339.mp3:
# Failed to process common_voice_en_547784.mp3:
# Failed to process common_voice_en_621407.mp3:
# Failed to process common_voice_en_19231865.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_19231865.mp3'
# Failed to process common_voice_en_571713.mp3:
# Failed to process common_voice_en_642484.mp3:
# Failed to process common_voice_en_61680.mp3:
# Failed to process common_voice_en_517900.mp3:
# Failed to process common_voice_en_38234.mp3:
# Failed to process common_voice_en_57837.mp3:
# Failed to process common_voice_en_482916.mp3:
# Failed to process common_voice_en_665545.mp3:
# Failed to process common_voice_en_642823.mp3:
# Failed to process common_voice_en_478633.mp3:
# Failed to process common_voice_en_547499.mp3:
# Failed to process common_voice_en_18001670.mp3: [Errno 2] No such file or directory: '../Data/common_voice_en_18001670.mp3'
# Failed to process common_voice_en_520000.mp3:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[25], line 80
#      78 fifties_df = pd.read_csv("fifties.csv")
#      79 twenties_df = pd.read_csv("twenties.csv")
# ---> 80 process_and_save_in_batches(males_df,"gender")
#      81 process_and_save_in_batches(females_df,"gender")
#      82 process_and_save_in_batches(fifties_df,"age")
#
# Cell In[25], line 71, in process_and_save_in_batches(df, type)
#      68     results = list(executor.map(extract_features, batch_files))
#      70 df = pd.DataFrame([res for res in results if res], columns=columns)
# ---> 71 df.to_csv(f"../CSVs/{type}/{i // BATCH_SIZE}.csv", index=False)
#      72 print(f"Saved batch {i // BATCH_SIZE} with {len(df)} entries.")
#      73 del df
#
# File d:\anaconda\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File d:\anaconda\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File d:\anaconda\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File d:\anaconda\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File d:\anaconda\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File d:\anaconda\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '..\CSVs\gender'

# %%
labels_df = pd.read_csv('filtered_data_labeled.tsv', sep='\t')
labels_df.head(10)
# Out:
#                                            client_id  \
# 0  5001d9a0d3f8f5aae6f386f70713b2d5d046edc7ba0068...
# 1  5001d9a0d3f8f5aae6f386f70713b2d5d046edc7ba0068...
# 2  5001d9a0d3f8f5aae6f386f70713b2d5d046edc7ba0068...
# 3  5001d9a0d3f8f5aae6f386f70713b2d5d046edc7ba0068...
# 4  5001d9a0d3f8f5aae6f386f70713b2d5d046edc7ba0068...
# 5  502a6d4e8f53be650018dd4a9097ab9287250e654b148c...
# 6  502a6d4e8f53be650018dd4a9097ab9287250e654b148c...
# 7  509994614d284ab2b1415df149ac1bdb05fef1adf8d33f...
# 8  509994614d284ab2b1415df149ac1bdb05fef1adf8d33f...
# 9  509994614d284ab2b1415df149ac1bdb05fef1adf8d33f...
#
#                            path  \
# 0  common_voice_en_19687170.mp3
# 1  common_voice_en_19687171.mp3
# 2  common_voice_en_19687172.mp3
# 3  common_voice_en_19687173.mp3
# 4  common_voice_en_19687174.mp3
# 5    common_voice_en_529569.mp3
# 6    common_voice_en_529573.mp3
# 7  common_voice_en_18421093.mp3
# 8  common_voice_en_18421094.mp3
# 9  common_voice_en_18421095.mp3
#
#                                             sentence  up_votes  down_votes  \
# 0                   He associated with the Formists.         2           1
# 1  The "ultra accelerator" injection gives Derric...         2           1
# 2  Despite running as a joke, candidates have won...         2           0
# 3  Stoner also guest-starred in the television dr...         2           0
# 4           Rainelle was named for the Raine family.         2           0
# 5                 He's insane or drunk or something.         2           0
# 6            I've been very busy the last few weeks.         2           0
# 7        He is a climate change sceptic. Good grief!         2           1
# 8         The director wasn't happy with the change.         2           0
# 9  The roof has been patched up many times over t...         2           0
#
#         age  gender   accent  label
# 0   fifties  female       us      3
# 1   fifties  female       us      3
# 2   fifties  female       us      3
# 3   fifties  female       us      3
# 4   fifties  female       us      3
# 5  twenties    male  england      0
# 6  twenties    male  england      0
# 7  twenties    male       us      0
# 8  twenties    male       us      0
# 9  twenties    male       us      0

# %%
import pandas as pd

# Load data
males_females_df = pd.read_csv('../CSVs/males_females.csv')
all_df = pd.read_csv('filtered_data_labeled.tsv', sep='\t')

# Find difference between the two DataFrames on the 'path' column
labels_df = all_df[~all_df['path'].isin(males_females_df['voiceID'])]

# %%
males_df = labels_df[labels_df["gender"]=="male"].sample(n=10000, random_state=1)
females_df = labels_df[labels_df["gender"]=="female"].sample(n=10000, random_state=1)
## save to csv
males_df.to_csv("males2.csv", index=False)
females_df.to_csv("females2.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3770 entries, 0 to 3769
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   voiceID              3770 non-null   object
#  1   duration             3770 non-null   float64
#  2   meanF0Hz             3770 non-null   float64
#  3   stdevF0Hz            3770 non-null   float64
#  4   HNR                  3770 non-null   float64
#  5   IQR                  3770 non-null   float64
#  6   sd                   3770 non-null   float64
#  7   sfm                  3770 non-null   float64
#  8   Q25                  3770 non-null   float64
#  9   sp.ent               3770 non-null   float64
#  10  mode                 3770 non-null   float64
#  11  localJitter          3770 non-null   float64
#  12  localabsoluteJitter  3770 non-null   float64
#  13  rapJitter            3770 non-null   float64
#  14  ppq5Jitter           3769 non-null   float64
#  15  ddpJitter            3770 non-null   float64
#  16  localShimmer         3770 non-null   float64
#  17  localdbShimmer       3770 non-null   float64
#  18  apq3Shimmer          3769 non-null   float64
#  19  apq5Shimmer          3768 non-null   float64
#  20  apq11Shimmer         3756 non-null   float64
#  21  ddaShimmer           3769 non-null   float64
#  22  f1_mean              3770 non-null   float64
#  23  f2_mean              3770 non-null   float64
#  24  f3_mean              3770 non-null   float64
#  25  f4_mean              3770 non-null   float64
#  26  f1_median            3770 non-null   float64
#  27  f2_median            3770 non-null   float64
#  28  f3_median            3770 non-null   float64
#  29  f4_median            3770 non-null   float64
# dtypes: float64(29), object(1)
# memory usage: 883.7+ KB

# %%
columns = df.columns
df[columns[1:]] = df[columns[1:]].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3770 entries, 0 to 3769
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   voiceID              3770 non-null   object
#  1   duration             3770 non-null   float64
#  2   meanF0Hz             3770 non-null   float64
#  3   stdevF0Hz            3770 non-null   float64
#  4   HNR                  3770 non-null   float64
#  5   IQR                  3770 non-null   float64
#  6   sd                   3770 non-null   float64
#  7   sfm                  3770 non-null   float64
#  8   Q25                  3770 non-null   float64
#  9   sp.ent               3770 non-null   float64
#  10  mode                 3770 non-null   float64
#  11  localJitter          3770 non-null   float64
#  12  localabsoluteJitter  3770 non-null   float64
#  13  rapJitter            3770 non-null   float64
#  14  ppq5Jitter           3769 non-null   float64
#  15  ddpJitter            3770 non-null   float64
#  16  localShimmer         3770 non-null   float64
#  17  localdbShimmer       3770 non-null   float64
#  18  apq3Shimmer          3769 non-null   float64
#  19  apq5Shimmer          3768 non-null   float64
#  20  apq11Shimmer         3756 non-null   float64
#  21  ddaShimmer           3769 non-null   float64
#  22  f1_mean              3770 non-null   float64
#  23  f2_mean              3770 non-null   float64
#  24  f3_mean              3770 non-null   float64
#  25  f4_mean              3770 non-null   float64
#  26  f1_median            3770 non-null   float64
#  27  f2_median            3770 non-null   float64
#  28  f3_median            3770 non-null   float64
#  29  f4_median            3770 non-null   float64
# dtypes: float64(29), object(1)
# memory usage: 883.7+ KB

# %%
df = df[~df.isna().any(axis=1)]

# %%
pcaData = runPCA(df) # Run jitter and shimmer PCA
df = pd.concat([df, pcaData], axis=1) # Add PCA data
# reload the data so it's all numbers
df.to_csv("common_features.csv", index=False)
# df = pd.read_csv('processed_results_2.csv', header=0)
df.sort_values('voiceID').head(20)
# Out:
#                                     voiceID  duration    meanF0Hz  stdevF0Hz  \
# 835     ../audio/common_voice_en_102830.mp3  3.008083  213.243396  40.068462
# 2226    ../audio/common_voice_en_109458.mp3  1.546687  145.115787  26.153789
# 2773  ../audio/common_voice_en_11017394.mp3  1.653417  159.343114  24.871168
# 3039    ../audio/common_voice_en_111906.mp3  3.616083  211.342513  43.745770
# 2335    ../audio/common_voice_en_111907.mp3  1.685437  223.577437  37.056594
# 1060    ../audio/common_voice_en_111908.mp3  2.336146  216.324266  27.084933
# 3552    ../audio/common_voice_en_111909.mp3  2.453583  207.804232  49.815519
# 2683    ../audio/common_voice_en_111910.mp3  2.080104  209.894623  41.380752
# 3765    ../audio/common_voice_en_111912.mp3  2.474813  210.921215  32.519464
# 3384    ../audio/common_voice_en_111913.mp3  2.069500  214.677739  30.047058
# 1244    ../audio/common_voice_en_111914.mp3  1.312104  216.157608  69.165775
# 1773    ../audio/common_voice_en_111916.mp3  2.570792  220.236927  25.544586
# 2186    ../audio/common_voice_en_111917.mp3  2.517500  202.326201  45.789871
# 803     ../audio/common_voice_en_111918.mp3  3.584396  213.907822  48.684615
# 1551    ../audio/common_voice_en_111919.mp3  2.144188  230.733605  21.860044
# 1386    ../audio/common_voice_en_111921.mp3  4.629646  212.364945  34.921158
# 735     ../audio/common_voice_en_111922.mp3  3.146958  208.727848  31.520493
# 3190    ../audio/common_voice_en_111923.mp3  1.706729  217.838912  31.810527
# 2922    ../audio/common_voice_en_111924.mp3  2.762812  208.290091  50.738447
# 742     ../audio/common_voice_en_111925.mp3  2.752187  222.489822  46.977837
#
#             HNR       IQR        sd       sfm       Q25       sp.ent  ...  \
# 835   11.100741  2.421097  2.717961  0.000115  0.899612 -1530.643707  ...
# 2226  12.804456  0.713129  1.316116  0.000060  0.436871 -2044.560213  ...
# 2773  12.792506  0.672118  1.630188  0.000425  0.606903 -2564.609795  ...
# 3039  15.405684  0.726714  1.233943  0.000135  0.629380 -1009.197949  ...
# 2335  15.662980  0.811675  1.637709  0.000047  0.576373 -1768.003979  ...
# 1060  17.191967  0.707230  1.212761  0.000665  0.444415 -2359.623297  ...
# 3552  12.060884  0.987408  1.302420  0.000242  0.749154 -2484.810513  ...
# 2683  15.616589  1.117807  1.555960  0.000236  0.693309 -1814.131462  ...
# 3765  16.307838  0.379963  0.871384  0.000194  0.614450 -1365.634930  ...
# 3384  18.034834  0.594433  1.507330  0.000203  0.483120 -2408.251382  ...
# 1244  14.536193  1.277213  1.501922  0.000047  0.610564 -2636.234469  ...
# 1773  18.181838  0.943699  1.522373  0.000112  0.460366 -1787.741498  ...
# 2186  13.820022  0.594238  1.432682  0.002181  0.691231 -1612.410002  ...
# 803   13.274888  1.401154  1.694955  0.002851  0.576906 -1773.532671  ...
# 1551  15.304261  0.855679  1.395312  0.000235  0.595375 -2801.401846  ...
# 1386  17.284752  0.687437  1.742681  0.000480  0.652367 -1148.139473  ...
# 735   14.255699  1.386404  1.336573  0.000570  0.461296 -1702.054003  ...
# 3190  17.397298  0.541406  1.594543  0.000394  0.461865 -2364.893564  ...
# 2922  16.440536  0.561570  1.048610  0.000151  0.619802 -1704.789024  ...
# 742   13.130384  0.692348  1.432970  0.000235  0.651419 -1174.936192  ...
#
#          f1_mean      f2_mean      f3_mean      f4_mean   f1_median  \
# 835   475.928627  1388.672370  2169.631822  3330.441756  488.812591
# 2226  450.444842  1363.676142  2222.358525  3224.555126  495.159733
# 2773  410.279735  1631.177873  2477.928332  3507.274608  392.467973
# 3039  489.191744  1340.149941  2161.417660  3075.593601  495.260087
# 2335  489.310341   986.262987  1926.305058  3357.936769  495.541551
# 1060  538.249477  1160.844761  2119.842303  3379.859736  507.094524
# 3552  494.764971  1702.435060  2475.511682  3699.697447  463.004273
# 2683  459.404828  1419.661197  2300.613115  3403.651786  448.896812
# 3765  478.169162  1253.843242  2213.795552  3525.079828  464.765269
# 3384  505.678092   973.511527  1768.249703  2995.732477  461.391523
# 1244  446.747764  1029.278193  2242.994272  3430.759894  460.958632
# 1773  482.598898  1139.038028  1847.396938  3340.372933  457.311036
# 2186  489.144246  1154.456725  2060.729944  3062.647371  467.964208
# 803   470.761940  1111.923066  1880.854709  3182.968663  449.588196
# 1551  586.107509  1343.933325  2176.850959  3226.524624  515.267200
# 1386  534.230262  1167.659834  1776.508842  3293.804723  505.639945
# 735   459.014952  1234.235575  2076.041987  3338.734581  394.141029
# 3190  469.946049  1006.411538  1887.869336  3177.426377  444.374628
# 2922  491.713992  1273.086917  2139.016997  3512.198001  471.423935
# 742   453.006974  1161.048135  2158.836877  3201.972678  425.552914
#
#         f2_median    f3_median    f4_median  JitterPCA  ShimmerPCA
# 835   1411.670381  1987.807183  3140.852555  -0.665802   -2.136635
# 2226  1499.968247  2341.971761  3242.537002  -1.206614    2.255931
# 2773  1596.197301  2596.258459  3641.383598  -0.958142    0.302211
# 3039  1164.903305  2035.771533  3062.980953  -3.983772    0.348359
# 2335   929.871759  1648.230695  3311.911520   7.079832    3.592096
# 1060  1184.931831  1897.566531  3406.758811  -1.812533   -0.711050
# 3552  1868.891081  2694.276217  3842.500482  -2.040233    0.653658
# 2683  1163.283949  2184.572612  3365.534142   0.536710    0.671469
# 3765  1095.951591  2292.066629  3722.026831        NaN         NaN
# 3384   977.828285  1499.700489  3065.745447  -1.814047   -0.773311
# 1244   890.007339  2301.429731  3366.206147  -1.004507   -1.502113
# 1773  1067.892492  1637.910959  3326.531013  -2.187023    0.691731
# 2186  1050.639026  1906.448309  3111.217122   4.113503   -0.043636
# 803    922.100050  1759.109319  3290.658056  -1.376147   -1.044156
# 1551  1238.226668  2113.326837  3304.126547  -1.893959    0.313920
# 1386  1144.281743  1571.447389  3360.144121   1.154566   -2.406826
# 735   1163.994688  1814.852324  3250.309068  -0.949190   -1.426966
# 3190   968.827053  1560.358353  3282.286730   4.664510    0.396645
# 2922  1203.516615  1754.315954  3804.761651   3.222781   -3.068192
# 742   1117.445592  2003.004090  3414.232570  -3.191599   -1.267420
#
# [20 rows x 32 columns]

# %%
df.head()
# Out:
#                                  voiceID  duration    meanF0Hz  stdevF0Hz  \
# 0  ../audio/common_voice_en_18534851.mp3  1.653417  222.014108  51.318958
# 1  ../audio/common_voice_en_19721473.mp3  3.658958  197.900264  36.011095
# 2  ../audio/common_voice_en_19065733.mp3  4.512229  205.211739  38.502619
# 3  ../audio/common_voice_en_19703218.mp3  3.530958  224.594040  33.974662
# 4  ../audio/common_voice_en_19647089.mp3  2.592146  214.070751  35.974475
#
#          HNR       IQR        sd       sfm       Q25       sp.ent  ...  \
# 0  16.829330  2.590946  2.357206  0.000144  0.561122 -2756.461625  ...
# 1  12.566395  1.456908  1.533911  0.000169  0.601329 -1791.164835  ...
# 2  11.249075  3.795021  2.017890  0.000100  0.755722 -1614.028249  ...
# 3  15.751549  1.626245  1.766607  0.000816  0.786259 -1287.487543  ...
# 4  10.610504  3.511184  2.139404  0.000139  1.287711 -1704.588366  ...
#
#       f1_mean      f2_mean      f3_mean      f4_mean   f1_median    f2_median  \
# 0  420.053422  1010.373773  2475.509873  3696.017683  279.806547   864.572129
# 1  509.093425  1493.826542  2126.930547  3061.389053  469.603179  1255.784879
# 2  504.372708  1503.906439  2171.456365  3316.511035  458.183243  1761.774514
# 3  507.858791  1748.850877  2476.726235  3658.137524  472.418650  1665.459675
# 4  559.687160  1720.476130  2372.949056  3472.616576  533.899874  1715.766331
#
#      f3_median    f4_median  JitterPCA  ShimmerPCA
# 0  2733.839435  3663.251888  -3.327086    0.095370
# 1  2036.851712  2891.063764  -1.810684    0.156760
# 2  2335.293541  3191.527166  -0.282858   -0.241512
# 3  2618.281868  3883.665380  -3.129440   -1.297744
# 4  2423.147832  3270.084778  -0.087711    1.686078
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Next we calculate the vocal-tract length estimates

# %% [markdown]
# ### Formant position
#  Puts, D. A., Apicella, C. L., & Cárdenas, R. A. (2012). Masculine voices signal men's threat potential in forager and industrial societies. Proceedings of the Royal Society of London B: Biological Sciences, 279(1728), 601-609.

# %%
df['pF'] = (zscore(df.f1_median) + zscore(df.f2_median) + zscore(df.f3_median) + zscore(df.f4_median)) / 4

# %% [markdown]
# ### Formant Dispersion
# Fitch, W. T. (1997). Vocal tract length and formant frequency dispersion correlate with body size in rhesus macaques. The Journal of the Acoustical Society of America, 102(2), 1213-1222.

# %%
df['fdisp'] = (df['f4_median'] - df['f1_median']) / 3

# %% [markdown]
# ### Fn (Average Formant)
# Pisanski, K., & Rendall, D. (2011). The prioritization of voice fundamental frequency or formants in listeners’ assessments of speaker size, masculinity, and attractiveness. The Journal of the Acoustical Society of America, 129(4), 2201-2212.

# %%
df['avgFormant'] = (df['f1_median'] + df['f2_median'] + df['f3_median'] + df['f4_median']) / 4

# %% [markdown]
# ### MFF
# Smith, D. R., & Patterson, R. D. (2005). The interaction of glottal-pulse rate and vocal-tract length in judgements of speaker size, sex, and age. The Journal of the Acoustical Society of America, 118(5), 3177-3186.

# %%
df['mff'] = (df['f1_median'] * df['f2_median'] * df['f3_median'] * df['f4_median']) ** 0.25

# %% [markdown]
# ### Fitch VTL
# Fitch, W. T. (1997). Vocal tract length and formant frequency dispersion correlate with body size in rhesus macaques. The Journal of the Acoustical Society of America, 102(2), 1213-1222.

# %%
# reload the data again
df.to_csv("common_features.csv", index=False)
df = pd.read_csv('common_features.csv', header=0)

df['fitch_vtl'] = ((1 * (35000 / (4 * df['f1_median']))) +
                   (3 * (35000 / (4 * df['f2_median']))) + 
                   (5 * (35000 / (4 * df['f3_median']))) + 
                   (7 * (35000 / (4 * df['f4_median'])))) / 4

# %% [markdown]
# ### $\Delta$F
# Reby,D.,& McComb,K.(2003). Anatomical constraints generate honesty: acoustic cues to age and weight in the roars of red deer stags. Animal Behaviour, 65, 519e-530.

# %%
xysum = (0.5 * df['f1_median']) + (1.5 * df['f2_median']) + (2.5 * df['f3_median']) + (3.5 * df['f4_median'])
xsquaredsum = (0.5 ** 2) + (1.5 ** 2) + (2.5 ** 2) + (3.5 ** 2)
df['delta_f'] = xysum / xsquaredsum

# %% [markdown]
# ### VTL($\Delta$F)
# Reby,D.,&McComb,K.(2003).Anatomical constraints generate honesty: acoustic cues to age and weight in the roars of red deer stags. Animal Behaviour, 65, 519e-530.

# %%
df['vtl_delta_f'] = 35000 / (2 * df['delta_f'])

# %% [markdown]
# ## Save the final data

# %%
# Write out the final dataframe
df.to_csv("common_features_final.csv", index=False)

# %% [markdown]
# ## Run this to tell you when it's done

# %%
print("finished")
raise SystemExit("Stopping notebook execution here.")
# Out:
# finished
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stopping notebook execution here.
# /home/aladdin/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pandas as pd
import numpy as np
import librosa
import parselmouth
from parselmouth.praat import call
from concurrent.futures import ProcessPoolExecutor

# %%
x = ['mean', 'var', 'min', 'max', 'p25', 'p75']
mfccColumns = [ f'{att}_{i}' for att in x for i in range(1, 14)]
mfccColumns.insert(0, 'voiceID')
print(mfccColumns)
# Out:
# ['voiceID', 'mean_1', 'mean_2', 'mean_3', 'mean_4', 'mean_5', 'mean_6', 'mean_7', 'mean_8', 'mean_9', 'mean_10', 'mean_11', 'mean_12', 'mean_13', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6', 'var_7', 'var_8', 'var_9', 'var_10', 'var_11', 'var_12', 'var_13', 'min_1', 'min_2', 'min_3', 'min_4', 'min_5', 'min_6', 'min_7', 'min_8', 'min_9', 'min_10', 'min_11', 'min_12', 'min_13', 'max_1', 'max_2', 'max_3', 'max_4', 'max_5', 'max_6', 'max_7', 'max_8', 'max_9', 'max_10', 'max_11', 'max_12', 'max_13', 'p25_1', 'p25_2', 'p25_3', 'p25_4', 'p25_5', 'p25_6', 'p25_7', 'p25_8', 'p25_9', 'p25_10', 'p25_11', 'p25_12', 'p25_13', 'p75_1', 'p75_2', 'p75_3', 'p75_4', 'p75_5', 'p75_6', 'p75_7', 'p75_8', 'p75_9', 'p75_10', 'p75_11', 'p75_12', 'p75_13']

# %%
def extract_mfcc_statistics(audio, sr, n_mfcc=13):
    # Extract MFCC features
    mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc)
    
    # Compute statistical summaries for each MFCC coefficient
    mfccs_mean = np.mean(mfccs, axis=1)  # Mean
    mfccs_var = np.var(mfccs, axis=1)    # Variance
    mfccs_min = np.min(mfccs, axis=1)    # Minimum
    mfccs_max = np.max(mfccs, axis=1)    # Maximum
    mfccs_percentile_25 = np.percentile(mfccs, 25, axis=1)  # 25th percentile
    mfccs_percentile_75 = np.percentile(mfccs, 75, axis=1)  # 75th percentile
    
    # Combine all statistics into a single feature vector
    mfcc_statistics = np.concatenate([
        mfccs_mean, mfccs_var, mfccs_min, mfccs_max, 
        mfccs_percentile_25, mfccs_percentile_75
    ])
    
    return mfcc_statistics

# %%
# Create an empty DataFrame
df = pd.DataFrame(columns=mfccColumns)

# Function to extract features from a single audio file
def extract_features(file_path):
    global mfccColumns
    try:
        # Load and preprocess the audio
        audio, sr = librosa.load(file_path, sr=None, mono=True)
        audio = remove_silence(audio)
        audio = normalize(audio)
        audio = nr.reduce_noise(y=audio, sr=sr)

        mfcc_stats = extract_mfcc_statistics(audio, sr)
        mfcc_stats = mfcc_stats.tolist()
        mfcc_stats.insert(0, file_path)

        f = { key: val for key, val in zip(mfccColumns, mfcc_stats)}

        return f
    except Exception as e:
        print(f"Failed to process {file_path}: {e}")
        return None

# Parallel processing of audio files
def process_audio_files(audio_files):
    global df
    with ProcessPoolExecutor() as executor:
        results = executor.map(extract_features, audio_files)

    # Append results to the DataFrame
    for result in results:
        if result:
            df = pd.concat([df, pd.DataFrame([result])], ignore_index=True)

# List all audio files
audio_files = glob.glob("../audio/*")

# Process files in parallel
process_audio_files(audio_files)

# Save the final DataFrame
df.to_csv("mfcc_features.csv", index=False)
print("Processing complete!")
# Out:
# /tmp/ipykernel_4558/1389253329.py:9: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(file_path, sr=None, mono=True)
# /home/aladdin/anaconda3/lib/python3.12/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Failed to process ../audio/common_voice_en_675766.mp3:
# /tmp/ipykernel_4558/1389253329.py:9: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(file_path, sr=None, mono=True)
# /home/aladdin/anaconda3/lib/python3.12/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Failed to process ../audio/common_voice_en_682788.mp3:
# Failed to process ../audio/common_voice_en_85538.mp3:
# Failed to process ../audio/common_voice_en_675768.mp3:
# /tmp/ipykernel_4558/1389253329.py:9: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(file_path, sr=None, mono=True)
# /home/aladdin/anaconda3/lib/python3.12/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Failed to process ../audio/common_voice_en_682785.mp3:
# /tmp/ipykernel_4558/1389253329.py:9: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(file_path, sr=None, mono=True)
# /home/aladdin/anaconda3/lib/python3.12/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Failed to process ../audio/common_voice_en_85541.mp3:
# Failed to process ../audio/common_voice_en_682778.mp3:
# Failed to process ../audio/common_voice_en_682782.mp3:
